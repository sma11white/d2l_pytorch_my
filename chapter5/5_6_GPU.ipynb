# %% [markdown]
# ## gpu

# %%
# !nvidia-smi # 展示gpu信息
# Out:
# Fri Sep 11 21:09:37 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   38C    P3             23W /  180W |    2439MiB /  16311MiB |     14%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            4824    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            4836    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            7124    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A            9544    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            9788    C+G   ...de\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           10488    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           10508    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10672    C+G   ....0.4191.66\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           12184    C+G   ...rograms\kimi-desktop\Kimi.exe      N/A      |
# |    0   N/A  N/A           12592    C+G   ....0.4191.66\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           13144    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           13940    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           14136    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           14840    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           16360    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           17872    C+G   ...lpaper_engine\wallpaper64.exe      N/A      |
# |    0   N/A  N/A           19276    C+G   C:\feishu\app\Feishu.exe              N/A      |
# |    0   N/A  N/A           20112    C+G   ...rograms\kimi-desktop\Kimi.exe      N/A      |
# |    0   N/A  N/A           22336    C+G   ...are\IntelGraphicsSoftware.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
from torch import nn

torch.device('cpu'), torch.device('cuda'), torch.device('cuda:1')
# Out:
# (device(type='cpu'), device(type='cuda'), device(type='cuda', index=1))

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
def try_gpu(i=0):  
    """如果存在，则返回gpu(i)，否则返回cpu()"""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')

def try_all_gpus():  
    """返回所有可用的GPU，如果没有GPU，则返回[cpu(),]"""
    devices = [torch.device(f'cuda:{i}')
             for i in range(torch.cuda.device_count())]
    return devices if devices else [torch.device('cpu')]

try_gpu(), try_gpu(10), try_all_gpus()
# Out:
# (device(type='cuda', index=0),
#  device(type='cpu'),
#  [device(type='cuda', index=0)])

# %%
x = torch.tensor([1, 2, 3])
x.device
# Out:
# device(type='cpu')

# %%
X = torch.ones(2, 3, device=try_gpu())
X
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')

# %%
# 我就一个gpu,改为cuda 0了
Y = torch.rand(2, 3, device=try_gpu(0))
Y,Y.device
# Out:
# (tensor([[0.2651, 0.3841, 0.5698],
#          [0.7039, 0.4119, 0.3455]], device='cuda:0'),
#  device(type='cuda', index=0))

# %%
# 我就一个gpu,改为cuda 0了
Z = X.cuda(0)
print(X)
print(Z)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')

# %%
Y + Z
# Out:
# tensor([[1.5666, 1.2019, 1.1762],
#         [1.4162, 1.9356, 1.1488]], device='cuda:0')

# %%
Z.cuda(0) is Z
# Out:
# True

# %%
net = nn.Sequential(nn.Linear(3, 1))
net = net.to(device=try_gpu())

# %%
net(X)
# Out:
# tensor([[-0.0292],
#         [-0.0292]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
net[0].weight.data.device
# Out:
# device(type='cuda', index=0)
